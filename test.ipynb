# %%
from sqlalchemy import create_engine
import psycopg2
from sqlalchemy_serializer import SerializerMixin
import pandas as pd

# %%
conn = psycopg2.connect(
    host = "nba-champs.c6ka6apltccn.us-east-2.rds.amazonaws.com",
    database="nbaChamps",
    user="postgres",
    password="MildredChase84!")

# %%
db_string = "postgresql+psycopg2://postgres:MildredChase84!@nba-champs.c6ka6apltccn.us-east-2.rds.amazonaws.com:5432/nbaChamps"

db = create_engine(db_string)
db
# Out:
# Engine(postgresql+psycopg2://postgres:***@nba-champs.c6ka6apltccn.us-east-2.rds.amazonaws.com:5432/nbaChamps)

# %%
engine = sqlalchemy.create_engine('postgresql://postgres:test1234@localhost:5432/sql-shack-demo')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-b9279d49cc84> in <module>
# ----> 1 engine = sqlalchemy.create_engine('postgresql://postgres:test1234@localhost:5432/sql-shack-demo')
#
# NameError: name 'sqlalchemy' is not defined

# %%
result_set = db.execute("select * from  all_stats")  
a_stats=[]
for r in result_set:  
      # print(r)

    a_stats.append(r)
    a_stats

# %%
a_stats
# Out:
# [(1, 'Atlanta Hawks', '2020-21', Decimal('-1.6'), Decimal('3.4'), Decimal('1'), '0'),
#  (2, 'Atlanta Hawks', '2019-20', Decimal('2.7'), Decimal('-3.4'), Decimal('4.2'), '0'),
#  (3, 'Atlanta Hawks', '2018-19', Decimal('3.9'), Decimal('-2.3'), Decimal('3.5'), '0'),
#  (4, 'Atlanta Hawks', '2017-18', Decimal('1'), Decimal('-3.6'), Decimal('2'), '0'),
#  (5, 'Atlanta Hawks', '2016-17', Decimal('1'), Decimal('-3.9'), Decimal('-3.1'), '0'),
#  (6, 'Atlanta Hawks', '2015-16', Decimal('1.3'), Decimal('-1.3'), Decimal('-5'), '0'),
#  (7, 'Atlanta Hawks', '2014-15', Decimal('0'), Decimal('3.3'), Decimal('-2.5'), '0'),
#  (8, 'Atlanta Hawks', '2013-14', Decimal('0.7'), Decimal('-0.8'), Decimal('-0.3'), '0'),
#  (9, 'Atlanta Hawks', '2012-13', Decimal('0.6'), Decimal('-1.1'), Decimal('-1.5'), '0'),
#  (10, 'Atlanta Hawks', '2011-12', Decimal('-1.1'), Decimal('0.3'), Decimal('-3.4'), '0'),
#  (11, 'Atlanta Hawks', '2010-11', Decimal('-2.8'), Decimal('-1.2'), Decimal('-0.3'), '0'),
# ...
